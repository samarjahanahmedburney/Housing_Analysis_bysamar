# %% [markdown]
# <a href="https://colab.research.google.com/github/samarjahanahmedburney/Housing_Analysis_bysamar/blob/main/story_telling_house.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading my CSV file into a pandas DataFrame
df=pd.read_csv("/content/sample_data/california_housing_test.csv")
print("\nHead of Dataset:")
df
# Out:
# Head of Dataset:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
print("\nSummary Statistics:")
df.head()
# Out:
# Summary Statistics:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
print("\nLast 5 Rows:")
df.tail()
# Out:
# Last 5 Rows:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
print("\nAll Column Names:")
df.columns
# Out:
# All Column Names:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
print("\nRows, Columns:")
df.shape
# Out:
# Rows, Columns:
# (3000, 9)

# %%
print("\nsummary:")
df.info()
# Out:
# summary:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
print("\nColumn DataType ")
df.dtypes
# Out:
# Column DataType
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# data cleaning

# %%
print("\nMissing Values:")
df.isnull().sum()
# Out:
# Missing Values:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
print("\nDuplicate Rows:")
df.duplicated()
# Out:
# Duplicate Rows:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
print("\nDuplicate and Unique Rows:")#true mean duplicate and false mean unique
df.duplicated().value_counts()
# Out:
# Duplicate and Unique Rows:
# False    3000
# Name: count, dtype: int64

# %%
print("\nSummary Statistics")
df.describe()
# Out:
# Summary Statistics
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# NUMERICAL COLUMNS

# %%
numer_column=df.select_dtypes(include=["int64","float64"]).columns
print(numer_column)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# CATEGORICAL COLUMNS

# %%
categ_column=df.select_dtypes(include=["bool","object","category"]).columns
print(categ_column)
# Out:
# Index([], dtype='object')

# %%
df_numerical=df[numer_column]
df_numerical
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
#compute STATISTIC
for col in df_numerical:
  print(f"Statstic for {col} :\n")
  print(f"Mean:{df[col].mean()}")
  print(f"Median:{df[col].median()}")
  print(f"Mode:{df[col].mode()[0]}")
  print(f"Standard Deviation:{df[col].std()}")
  print(f"Variance:{df[col].var()}")
  print(f"Skewness:{df[col].skew()}")
  print(f"Kurtosis:{df[col].kurt()}")
  print(f"Maximum:{df[col].max()}")
  print(f"Minimum:{df[col].min()}")
# Out:
# Statstic for longitude :
#
# Mean:-119.58919999999999
# Median:-118.485
# Mode:-118.26
# Standard Deviation:1.9949362939550161
# Variance:3.9797708169389745
# Skewness:-0.29785763262779996
# Kurtosis:-1.3627716597885198
# Maximum:-114.49
# Minimum:-124.18
# Statstic for latitude :
#
# Mean:35.635389999999994
# Median:34.27
# Mode:34.02
# Standard Deviation:2.1296695233438325
# Variance:4.5354922786595475
# Skewness:0.45981593679052085
# Kurtosis:-1.1243724704483558
# Maximum:41.92
# Minimum:32.56
# Statstic for housing_median_age :
#
# Mean:28.845333333333333
# Median:29.0
# Mode:52.0
# Standard Deviation:12.555395554955755
# Variance:157.63795754140273
# Skewness:0.018513121159991593
# Kurtosis:-0.8037837284188449
# Maximum:52.0
# Minimum:1.0
# Statstic for total_rooms :
#
# Mean:2599.578666666667
# Median:2106.0
# Mode:907.0
# Standard Deviation:2155.59333162558
# Variance:4646582.611348667
# Skewness:4.167637358501556
# Kurtosis:32.09994094352687
# Maximum:30450.0
# Minimum:6.0
# ...

# %% [markdown]
# DATA VISUALIZATION

# %%
#Histogram for numerical column
df_numerical.hist(figsize=(8,10),bins=20,edgecolor="black")
plt.tight_layout()
plt.show()

# %%
#Boxplot to detect outliers
for col  in numer_column:
  plt.figure(figsize=(6,2))
  sns.boxplot(x=df[col])
  plt.title(f"Boxplot of {col}")
  plt.show()

# %% [markdown]
# # **story telling**

# %%
#Storytelling
story = '''
I analyzed the housing prices dataset, focusing on variables such as price, area, and number of bedrooms.
The average price of homes was high, but the distribution was right-skewed, showing a few very expensive houses pulling the average upward.
The standard deviation and variance in price and area suggest large variability, indicating a diverse market.
Most homes had 2 to 4 bedrooms, and while larger homes generally had higher prices, some outliers were priced lower than expected.
This might be due to poor condition or location farther from main roads.
The box plot and scatter plot revealed both typical trends and some unusual entries worth deeper investigation.
Overall, the housing market shown in this dataset appears mixed, where both size and non-numeric features (like location and furnishing) play roles.
'''
print("\n--- Data Story ---")
print(story)
# Out:
# --- Data Story ---
#
# I analyzed the housing prices dataset, focusing on variables such as price, area, and number of bedrooms.
# The average price of homes was high, but the distribution was right-skewed, showing a few very expensive houses pulling the average upward.
# The standard deviation and variance in price and area suggest large variability, indicating a diverse market.
# Most homes had 2 to 4 bedrooms, and while larger homes generally had higher prices, some outliers were priced lower than expected.
# This might be due to poor condition or location farther from main roads.
# The box plot and scatter plot revealed both typical trends and some unusual entries worth deeper investigation.
# Overall, the housing market shown in this dataset appears mixed, where both size and non-numeric features (like location and furnishing) play roles.
